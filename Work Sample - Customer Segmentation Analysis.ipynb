# %% [markdown]
# # Customer Segmentation Analysis
#
# ### Summary
# I started by exploring and cleaning a dataset of 9,800 product orders. I constructed a recency, frequency, and montetary analysis from this data to segment our customers. Utilizing a machine learning algorithm, I identified our low, mid, and high value customers. Once I classifed our customer base, I calculated the customer lifetime value of each group.
#
# The primary difference between low and mid tier customers is the time since their last purchase. Mid tier customers have purchased products more recently. Converting low tier customers to mid tier customers will generate the largest increase in customer lifetime value. I identified the top products our low tier customers purchased and proposed we offer a one-time discount on these products for those customers to encourage them to start making purchases from our company again.
#
# Additionally, I identified the products that generate the most sales amongst our high value customers. We can consider offering a loyalty program to these customers to encourage them to continue buying these products. We also may consider expanding our product offerings for these sub-categories as they generate the most sales amongst our best customers.
#
# Another option is asking for customer feedback to understand the best aspects of these products so we can better market them to our low and mid tier customers.
#
# Furthermore, I can import our product order dataframe with the newly added customer value chorts into a visualization tool like Looker to identify more trends and insights. I can present a variety of visualizations showcasing sales performance on a regional basis, within customer segments, or dive deeper into category and sub-category product trends to name a few.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('Data/superstore-sales.csv', parse_dates=['Order Date', 'Ship Date'], dayfirst=True)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
# Do not need Row ID
df.drop('Row ID', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   object
#  1   Order Date     9800 non-null   datetime64[ns]
#  2   Ship Date      9800 non-null   datetime64[ns]
#  3   Ship Mode      9800 non-null   object
#  4   Customer ID    9800 non-null   object
#  5   Customer Name  9800 non-null   object
#  6   Segment        9800 non-null   object
#  7   Country        9800 non-null   object
#  8   City           9800 non-null   object
#  9   State          9800 non-null   object
#  10  Postal Code    9789 non-null   float64
#  11  Region         9800 non-null   object
#  12  Product ID     9800 non-null   object
#  13  Category       9800 non-null   object
#  14  Sub-Category   9800 non-null   object
#  15  Product Name   9800 non-null   object
#  16  Sales          9800 non-null   float64
# dtypes: datetime64[ns](2), float64(2), object(13)
# memory usage: 1.3+ MB

# %%
# Find null values in "Postal Code"
df[df["Postal Code"].isnull()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2018-104066 2018-12-05 2018-12-10  Standard Class    QJ-19255
# 5274  CA-2016-162887 2016-11-07 2016-11-09    Second Class    SV-20785
# 8798  US-2017-150140 2017-04-06 2017-04-10  Standard Class    VM-21685
# 9146  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9147  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9148  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9386  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9387  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9388  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9389  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9741  CA-2016-117086 2016-11-08 2016-11-12  Standard Class    QJ-19255
#
#          Customer Name      Segment        Country        City    State  \
# 2234      Quincy Jones    Corporate  United States  Burlington  Vermont
# 5274  Stewart Visinsky     Consumer  United States  Burlington  Vermont
# 8798   Valerie Mitchum  Home Office  United States  Burlington  Vermont
# 9146  Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9147  Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9148  Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9386     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9387     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9388     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9389     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9741      Quincy Jones    Corporate  United States  Burlington  Vermont
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 2234          NaN   East  TEC-AC-10001013       Technology  Accessories
# 5274          NaN   East  FUR-CH-10000595        Furniture       Chairs
# 8798          NaN   East  TEC-PH-10002555       Technology       Phones
# 9146          NaN   East  TEC-AC-10002926       Technology  Accessories
# 9147          NaN   East  OFF-AR-10003477  Office Supplies          Art
# 9148          NaN   East  OFF-ST-10001526  Office Supplies      Storage
# 9386          NaN   East  OFF-PA-10000157  Office Supplies        Paper
# 9387          NaN   East  OFF-PA-10001970  Office Supplies        Paper
# 9388          NaN   East  OFF-AP-10000828  Office Supplies   Appliances
# 9389          NaN   East  OFF-EN-10001509  Office Supplies    Envelopes
# 9741          NaN   East  FUR-BO-10004834        Furniture    Bookcases
#
#                                            Product Name    Sales
# 2234        Logitech ClearChat Comfort/USB Headset H390   205.03
# 5274                    Safco Contoured Stacking Chairs   715.20
# 8798                Nortel Meridian M5316 Digital phone  1294.75
# 9146              Logitech Wireless Marathon Mouse M705    99.98
# 9147                                  4009 Highlighters     8.04
# 9148              Iceberg Mobile Mega Data/Printer Cart  1564.29
# 9386                                          Xerox 191    79.92
# 9387                                         Xerox 1881    12.28
# 9388                    Avanti 4.4 Cu. Ft. Refrigerator   542.94
# 9389                          Poly String Tie Envelopes     2.04
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90

# %%
# Confirm all Burlington, Vermont postal codes are null
df.loc[(df['City'] == 'Burlington') & (df['State'] == 'Vermont')]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2018-104066 2018-12-05 2018-12-10  Standard Class    QJ-19255
# 5274  CA-2016-162887 2016-11-07 2016-11-09    Second Class    SV-20785
# 8798  US-2017-150140 2017-04-06 2017-04-10  Standard Class    VM-21685
# 9146  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9147  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9148  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9386  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9387  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9388  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9389  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9741  CA-2016-117086 2016-11-08 2016-11-12  Standard Class    QJ-19255
#
#          Customer Name      Segment        Country        City    State  \
# 2234      Quincy Jones    Corporate  United States  Burlington  Vermont
# 5274  Stewart Visinsky     Consumer  United States  Burlington  Vermont
# 8798   Valerie Mitchum  Home Office  United States  Burlington  Vermont
# 9146  Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9147  Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9148  Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9386     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9387     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9388     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9389     Raymond Messe     Consumer  United States  Burlington  Vermont
# 9741      Quincy Jones    Corporate  United States  Burlington  Vermont
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 2234          NaN   East  TEC-AC-10001013       Technology  Accessories
# 5274          NaN   East  FUR-CH-10000595        Furniture       Chairs
# 8798          NaN   East  TEC-PH-10002555       Technology       Phones
# 9146          NaN   East  TEC-AC-10002926       Technology  Accessories
# 9147          NaN   East  OFF-AR-10003477  Office Supplies          Art
# 9148          NaN   East  OFF-ST-10001526  Office Supplies      Storage
# 9386          NaN   East  OFF-PA-10000157  Office Supplies        Paper
# 9387          NaN   East  OFF-PA-10001970  Office Supplies        Paper
# 9388          NaN   East  OFF-AP-10000828  Office Supplies   Appliances
# 9389          NaN   East  OFF-EN-10001509  Office Supplies    Envelopes
# 9741          NaN   East  FUR-BO-10004834        Furniture    Bookcases
#
#                                            Product Name    Sales
# 2234        Logitech ClearChat Comfort/USB Headset H390   205.03
# 5274                    Safco Contoured Stacking Chairs   715.20
# 8798                Nortel Meridian M5316 Digital phone  1294.75
# 9146              Logitech Wireless Marathon Mouse M705    99.98
# 9147                                  4009 Highlighters     8.04
# 9148              Iceberg Mobile Mega Data/Printer Cart  1564.29
# 9386                                          Xerox 191    79.92
# 9387                                         Xerox 1881    12.28
# 9388                    Avanti 4.4 Cu. Ft. Refrigerator   542.94
# 9389                          Poly String Tie Envelopes     2.04
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90

# %%
# Replace null 'Postal Code' in Burlington, Vermont with a Burlington, VT Postal Code
df["Postal Code"].fillna("05401", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   object
#  1   Order Date     9800 non-null   datetime64[ns]
#  2   Ship Date      9800 non-null   datetime64[ns]
#  3   Ship Mode      9800 non-null   object
#  4   Customer ID    9800 non-null   object
#  5   Customer Name  9800 non-null   object
#  6   Segment        9800 non-null   object
#  7   Country        9800 non-null   object
#  8   City           9800 non-null   object
#  9   State          9800 non-null   object
#  10  Postal Code    9800 non-null   object
#  11  Region         9800 non-null   object
#  12  Product ID     9800 non-null   object
#  13  Category       9800 non-null   object
#  14  Sub-Category   9800 non-null   object
#  15  Product Name   9800 non-null   object
#  16  Sales          9800 non-null   float64
# dtypes: datetime64[ns](2), float64(1), object(14)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#               Sales
# count   9800.000000
# mean     230.769059
# std      626.651875
# min        0.444000
# 25%       17.248000
# 50%       54.490000
# 75%      210.605000
# max    22638.480000

# %%
# Check for duplicate values
df.loc[df.duplicated(), :]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2015-150119 2015-04-23 2015-04-27  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State Postal Code  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio     43229.0
#
#      Region       Product ID   Category Sub-Category  \
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales
# 3406  Global Leather Highback Executive Chair with P...  281.372

# %% [markdown]
# Since there is only 1 duplicate and it's for chairs, we are going to leave it in the dataset. It's reasonable to think someone ordered multiple chairs. Overall, it appears there are no erroneous duplicates in the dataset.

# %%
# Remove decimals from "Postal Code" column so its only 5 digits
df = df.astype({'Postal Code':'string'})

# %%
clean_postal = df['Postal Code']

# %%
PostalCode = []
for p in clean_postal:
    PostalCode.append(p[:5])

# %%
PostalCode[:5]
# Out:
# ['42420', '42420', '90036', '33311', '33311']

# %%
df.drop(['Postal Code'], axis=1, inplace=True)

# %%
df.insert(loc=9, column='Postal Code', value=PostalCode)

# %%
# Round sales column to two decimals
df['Sales'] = df['Sales'].round(decimals=2)

# %%
df.head(5)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City Postal Code  \
# 0      Claire Gute   Consumer  United States        Henderson       42420
# 1      Claire Gute   Consumer  United States        Henderson       42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles       90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale       33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale       33311
#
#         State Region       Product ID         Category Sub-Category  \
# 0    Kentucky  South  FUR-BO-10001798        Furniture    Bookcases
# 1    Kentucky  South  FUR-CH-10000454        Furniture       Chairs
# 2  California   West  OFF-LA-10000240  Office Supplies       Labels
# 3     Florida  South  FUR-TA-10000577        Furniture       Tables
# 4     Florida  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
# 3      Bretford CR4500 Series Slim Rectangular Table  957.58
# 4                     Eldon Fold 'N Roll Cart System   22.37

# %%
# Explore the sales data to see if there appears to be any missing dates or input errors
sales = df.groupby(df['Order Date'])['Sales'].sum()
sales
# Out:
# Order Date
# 2015-01-03      16.45
# 2015-01-04     288.06
# 2015-01-05      19.54
# 2015-01-06    4407.10
# 2015-01-07      87.16
#                ...
# 2018-12-26     814.59
# 2018-12-27     177.64
# 2018-12-28    1657.34
# 2018-12-29    2915.54
# 2018-12-30     713.79
# Name: Sales, Length: 1230, dtype: float64

# %%
sales.plot()
# Out:
# <AxesSubplot: xlabel='Order Date'>

# %%
from datetime import datetime 

mindate = df['Order Date'].min()
maxdate = df['Order Date'].max()
min = sales.min()
max = sales.max()
range = max-min

print("The sales data shows sales from {} to {}. The amount of sales in a day ranges from ${:,.2f} to ${:,.2f}. There are no order dates without sales.".format(mindate.strftime("%B %-d, %Y"), maxdate.strftime("%B %-d, %Y"), min, max))
# Out:
# The sales data shows sales from January 3, 2015 to December 30, 2018. The amount of sales in a day ranges from $2.02 to $28,106.73. There are no order dates without sales.

# %%
# Check sales data to see if any outliers may be errors
fig, ax = plt.subplots(figsize=(16, 3))
plt.boxplot(sales, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15d6949a0>,
#   <matplotlib.lines.Line2D at 0x15d694c40>],
#  'caps': [<matplotlib.lines.Line2D at 0x15d694ee0>,
#   <matplotlib.lines.Line2D at 0x15d695180>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15d694700>],
#  'medians': [<matplotlib.lines.Line2D at 0x15d695420>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15d6956c0>],
#  'means': []}

# %%
# Check order dates that have sales over $15,000
high_sales = sales[sales > 15000].sort_values(ascending=False)
high_sales
# Out:
# Order Date
# 2015-03-18    28106.73
# 2017-10-02    18452.97
# 2018-10-22    15158.88
# Name: Sales, dtype: float64

# %%
target_dates = high_sales.index.to_list()
high_sales_dates = df.loc[df['Order Date'].isin(target_dates)]
high_sales_dates
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2623  CA-2018-127180 2018-10-22 2018-10-24     First Class    TA-21385
# 2624  CA-2018-127180 2018-10-22 2018-10-24     First Class    TA-21385
# 2625  CA-2018-127180 2018-10-22 2018-10-24     First Class    TA-21385
# 2626  CA-2018-127180 2018-10-22 2018-10-24     First Class    TA-21385
# 2696  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2697  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2698  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2699  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2700  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2701  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2702  CA-2015-145317 2015-03-18 2015-03-23  Standard Class    SM-20320
# 2992  CA-2017-134376 2017-10-02 2017-10-06  Standard Class    TT-21265
# 4294  CA-2018-101581 2018-10-22 2018-10-27  Standard Class    DW-13195
# 4477  CA-2018-130211 2018-10-22 2018-10-22        Same Day    BD-11620
# 4478  CA-2018-130211 2018-10-22 2018-10-22        Same Day    BD-11620
# 4512  CA-2017-118969 2017-10-02 2017-10-03     First Class    LP-17095
# 4515  US-2018-111920 2018-10-22 2018-10-26  Standard Class    PS-18970
# 4641  CA-2018-130141 2018-10-22 2018-10-24    Second Class    HA-14905
# 4642  CA-2018-130141 2018-10-22 2018-10-24    Second Class    HA-14905
# 6151  CA-2015-111871 2015-03-18 2015-03-21    Second Class    EK-13795
# 6825  CA-2017-118689 2017-10-02 2017-10-09  Standard Class    TC-20980
# 6826  CA-2017-118689 2017-10-02 2017-10-09  Standard Class    TC-20980
# 6827  CA-2017-118689 2017-10-02 2017-10-09  Standard Class    TC-20980
# 6828  CA-2017-118689 2017-10-02 2017-10-09  Standard Class    TC-20980
# 6829  CA-2017-118689 2017-10-02 2017-10-09  Standard Class    TC-20980
# 7262  CA-2018-156363 2018-10-22 2018-10-28  Standard Class    ML-17395
# 7263  CA-2018-156363 2018-10-22 2018-10-28  Standard Class    ML-17395
# 7327  US-2015-131275 2015-03-18 2015-03-24  Standard Class    SC-20050
# 7328  US-2015-131275 2015-03-18 2015-03-24  Standard Class    SC-20050
# 7329  US-2015-131275 2015-03-18 2015-03-24  Standard Class    SC-20050
#
#             Customer Name      Segment        Country           City  \
# 2623         Tom Ashbrook  Home Office  United States  New York City
# 2624         Tom Ashbrook  Home Office  United States  New York City
# 2625         Tom Ashbrook  Home Office  United States  New York City
# 2626         Tom Ashbrook  Home Office  United States  New York City
# 2696          Sean Miller  Home Office  United States   Jacksonville
# 2697          Sean Miller  Home Office  United States   Jacksonville
# 2698          Sean Miller  Home Office  United States   Jacksonville
# 2699          Sean Miller  Home Office  United States   Jacksonville
# 2700          Sean Miller  Home Office  United States   Jacksonville
# 2701          Sean Miller  Home Office  United States   Jacksonville
# 2702          Sean Miller  Home Office  United States   Jacksonville
# 2992          Tim Taslimi    Corporate  United States  New York City
# 4294         David Wiener    Corporate  United States        Redmond
# 4477      Brian DeCherney     Consumer  United States         Lawton
# 4478      Brian DeCherney     Consumer  United States         Lawton
# 4512            Liz Preis     Consumer  United States        Phoenix
# 4515       Paul Stevenson  Home Office  United States          Tulsa
# 4641        Helen Abelman     Consumer  United States   Fort Collins
# 4642        Helen Abelman     Consumer  United States   Fort Collins
# 6151        Eileen Kiefer  Home Office  United States  San Francisco
# 6825         Tamara Chand    Corporate  United States      Lafayette
# 6826         Tamara Chand    Corporate  United States      Lafayette
# 6827         Tamara Chand    Corporate  United States      Lafayette
# 6828         Tamara Chand    Corporate  United States      Lafayette
# 6829         Tamara Chand    Corporate  United States      Lafayette
# 7262  Marina Lichtenstein    Corporate  United States   Philadelphia
# 7263  Marina Lichtenstein    Corporate  United States   Philadelphia
# 7327     Sample Company A  Home Office  United States        Burbank
# 7328     Sample Company A  Home Office  United States        Burbank
# 7329     Sample Company A  Home Office  United States        Burbank
#
#      Postal Code         State   Region       Product ID         Category  \
# 2623       10024      New York     East  TEC-CO-10004722       Technology
# 2624       10024      New York     East  TEC-PH-10001494       Technology
# 2625       10024      New York     East  OFF-EN-10002500  Office Supplies
# 2626       10024      New York     East  TEC-PH-10003800       Technology
# 2696       32216       Florida    South  TEC-MA-10003626       Technology
# 2697       32216       Florida    South  TEC-MA-10002412       Technology
# 2698       32216       Florida    South  OFF-PA-10001804  Office Supplies
# 2699       32216       Florida    South  OFF-AR-10003183  Office Supplies
# 2700       32216       Florida    South  FUR-FU-10004270        Furniture
# 2701       32216       Florida    South  OFF-FA-10003112  Office Supplies
# 2702       32216       Florida    South  FUR-FU-10001986        Furniture
# 2992       10024      New York     East  OFF-AP-10004532  Office Supplies
# 4294       97756        Oregon     West  FUR-TA-10002607        Furniture
# 4477       73505      Oklahoma  Central  OFF-ST-10000129  Office Supplies
# 4478       73505      Oklahoma  Central  FUR-TA-10003748        Furniture
# 4512       85023       Arizona     West  OFF-BI-10002429  Office Supplies
# 4515       74133      Oklahoma  Central  OFF-AR-10003179  Office Supplies
# 4641       80525      Colorado     West  OFF-BI-10000831  Office Supplies
# 4642       80525      Colorado     West  FUR-CH-10000749        Furniture
# 6151       94110    California     West  FUR-BO-10004218        Furniture
# 6825       47905       Indiana  Central  OFF-ST-10001558  Office Supplies
# 6826       47905       Indiana  Central  TEC-CO-10004722       Technology
# 6827       47905       Indiana  Central  OFF-BI-10004600  Office Supplies
# 6828       47905       Indiana  Central  OFF-BI-10003712  Office Supplies
# 6829       47905       Indiana  Central  OFF-AR-10001958  Office Supplies
# 7262       19134  Pennsylvania     East  TEC-PH-10003988       Technology
# 7263       19134  Pennsylvania     East  OFF-EN-10003068  Office Supplies
# 7327       91505    California     West  FUR-FU-10004597        Furniture
# 7328       91505    California     West  TEC-MA-10001148       Technology
# 7329       91505    California     West  OFF-ST-10000078  Office Supplies
#
#      Sub-Category                                       Product Name     Sales
# 2623      Copiers              Canon imageCLASS 2200 Advanced Copier  11199.97
# 2624       Phones                  Polycom CX600 IP Phone VoIP phone   2399.60
# 2625    Envelopes       Globe Weis Peel & Seel First Class Envelopes     63.90
# 2626       Phones                  i.Sound Portable Power - 8000 mAh     52.99
# 2696     Machines  Hewlett-Packard Deskjet 6540 Color Inkjet Printer    821.30
# 2697     Machines  Cisco TelePresence System EX90 Videoconferenci...  22638.48
# 2698        Paper                                          Xerox 195     21.38
# 2699          Art       Avery Fluorescent Highlighter Four-Color Set      8.02
# 2700  Furnishings     Executive Impressions 13" Clairmont Wall Clock     30.77
# 2701    Fasteners                                            Staples     18.94
# 2702  Furnishings       Dana Fluorescent Magnifying Lamp, White, 36"    122.35
# 2992   Appliances  Kensington 6 Outlet Guardian Standard Surge Pr...     61.44
# 4294       Tables                               KI Conference Tables    177.22
# 4477      Storage                  Fellowes Recycled Storage Drawers    333.09
# 4478       Tables                    Bevis 36 x 72 Conference Tables    248.98
# 4512      Binders              Premier Elliptical Ring Binder, Black     54.79
# 4515          Art        Dixon Ticonderoga Core-Lock Colored Pencils     36.44
# 4641      Binders   Storex Flexible Poly Binders with Double Pockets      3.17
# 4642       Chairs  Office Star - Ergonomic Mid Back Chair with 2-...    579.14
# 6151    Bookcases  Bush Heritage Pine Collection 5-Shelf Bookcase...   1198.33
# 6825      Storage           Acco Perma 4000 Stacking Storage Drawers     32.48
# 6826      Copiers              Canon imageCLASS 2200 Advanced Copier  17499.95
# 6827      Binders          Ibico Ibimaster 300 Manual Binding System    735.98
# 6828      Binders  Acco Pressboard Covers with Storage Hooks, 14 ...     34.37
# 6829          Art  Stanley Bostitch Contemporary Electric Pencil ...     33.96
# 7262       Phones  LF Elite 3D Dazzle Designer Hard Case Cover, L...     32.70
# 7263    Envelopes                 #6 3/4 Gummed Flap White Envelopes     31.68
# 7327  Furnishings  Eldon Cleatmat Chair Mats for Medium Pile Carpets    111.00
# 7328     Machines       Swingline SM12-08 MicroCut Jam Free Shredder   1279.97
# 7329      Storage              Tennsco 6- and 18-Compartment Lockers   1856.19

# %% [markdown]
# The the order dates with the 3 highest sales all appear to be accurate. The high sales values are associated with technology purchases on these dates.

# %% [markdown]
# # Customer Segmentation Analysis
# Now that the we have explored and cleaned the data, we will begin segmenting our customers to create personalized marketing, improve customer retention, and increase resource efficiency

# %%
df.head(5)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City Postal Code  \
# 0      Claire Gute   Consumer  United States        Henderson       42420
# 1      Claire Gute   Consumer  United States        Henderson       42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles       90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale       33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale       33311
#
#         State Region       Product ID         Category Sub-Category  \
# 0    Kentucky  South  FUR-BO-10001798        Furniture    Bookcases
# 1    Kentucky  South  FUR-CH-10000454        Furniture       Chairs
# 2  California   West  OFF-LA-10000240  Office Supplies       Labels
# 3     Florida  South  FUR-TA-10000577        Furniture       Tables
# 4     Florida  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62
# 3      Bretford CR4500 Series Slim Rectangular Table  957.58
# 4                     Eldon Fold 'N Roll Cart System   22.37

# %%
# Create pin date to calculate number of days from the customer's most recent purchase and the end of the dataset. 
pin_date = df['Order Date'].max() + dt.timedelta(days=1)

# Create Recency, Frequency, and Monetary Value dataframe grouped by customer ID
rfm = df.groupby(['Customer ID']).agg({
    'Order Date':lambda x : (pin_date-x.max()).days,
    'Order ID' : 'count',
    'Sales' : 'sum'
})
rfm = rfm.rename(columns={'Order Date':'Recency','Order ID':'Frequency','Sales':'Monetary'})

# %%
rfm
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# AA-10315         185         11   5563.56
# AA-10375          20         15   1056.39
# AA-10480         260         12   1790.51
# AA-10645          56         18   5086.93
# AB-10015         416          6    886.15
# ...              ...        ...       ...
# XP-21865          44         28   2374.66
# YC-21895           5          8   5454.35
# YS-21880          10         12   6720.44
# ZC-21910          55         31   8025.70
# ZD-21925         203          9   1493.94
#
# [793 rows x 3 columns]

# %%
rfm.shape
# Out:
# (793, 3)

# %% [markdown]
# We have 793 unique customers.

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 793 entries, AA-10315 to ZD-21925
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    793 non-null    int64
#  1   Frequency  793 non-null    int64
#  2   Monetary   793 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 24.8+ KB

# %%
rfm.describe()
# Out:
#            Recency   Frequency      Monetary
# count   793.000000  793.000000    793.000000
# mean    149.286255   12.358134   2851.874590
# std     187.081466    6.162600   2620.668725
# min       1.000000    1.000000      4.830000
# 25%      31.000000    8.000000   1081.470000
# 50%      76.000000   11.000000   2214.990000
# 75%     185.000000   16.000000   3670.270000
# max    1166.000000   35.000000  25043.070000

# %%
# Examine the distribution of the recency, frequency, and monetary data
rfm.hist(figsize=(16,8))
# Out:
# array([[<AxesSubplot: title={'center': 'Recency'}>,
#         <AxesSubplot: title={'center': 'Frequency'}>],
#        [<AxesSubplot: title={'center': 'Monetary'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
# Recency and monetary are skewed right so we will normalize the data by applying the log function. Frequency has some right skew but not enough skew to warrant applying the log function.
rfm['Recency'] = rfm['Recency'].apply(np.log, axis=1)
rfm['Monetary'] = rfm['Monetary'].apply(np.log, axis=1)
rfm.hist(figsize=(16,8))
# Out:
# array([[<AxesSubplot: title={'center': 'Recency'}>,
#         <AxesSubplot: title={'center': 'Frequency'}>],
#        [<AxesSubplot: title={'center': 'Monetary'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(rfm)

# %%
# Use elbow method to determine number of clusters for segmenting customers
wcss = []
for i in np.arange(1,11):
    kmeans = KMeans(n_clusters=i, n_init=10, init='k-means++', random_state=0)
    kmeans.fit(scaled)
    wcss.append(kmeans.inertia_)

plt.plot(np.arange(1,11), wcss, marker='o')
plt.title("The Elbow Method")
plt.xlabel("No. of Clusters")
plt.ylabel("WCSS Score")
# Out:
# Text(0, 0.5, 'WCSS Score')

# %%
# The elbow method suggests clustering the data in 3 or 4 clusters as it appears to be the point where the decrease in within-cluster sum of squares (WCSS) begins to flatten. We decided to choose 3 clusters
kmeans = KMeans(n_clusters=3, n_init=10, init='k-means++')
kmeans.fit(scaled)
rfm['Clusters']=(kmeans.labels_ + 1)

# %%
rfm
# Out:
#               Recency  Frequency  Monetary  Clusters
# Customer ID
# AA-10315     5.220356         11  8.623993         2
# AA-10375     2.995732         15  6.962613         3
# AA-10480     5.560682         12  7.490256         1
# AA-10645     4.025352         18  8.534430         2
# AB-10015     6.030685          6  6.786886         1
# ...               ...        ...       ...       ...
# XP-21865     3.784190         28  7.772610         2
# YC-21895     1.609438          8  8.604169         3
# YS-21880     2.302585         12  8.812909         3
# ZC-21910     4.007333         31  8.990404         2
# ZD-21925     5.313206          9  7.309172         1
#
# [793 rows x 4 columns]

# %%
# After segmenting the customers into 3 groups, we will explore what the segments represent
customer_value = rfm.groupby(['Clusters'])[['Recency','Frequency','Monetary']].mean()
customer_value
# Out:
#            Recency  Frequency  Monetary
# Clusters
# 1         5.280668   7.784053  6.733633
# 2         4.246787  18.512821  8.353841
# 3         2.952824  10.972603  7.603176

# %%
# We identified customers in segment 2 as high value, customers in segment 3 as mid value and customers in segment 1 as low value.
def func(row):
    if row['Clusters'] == 2:
        return 'High'
    elif row['Clusters'] == 3:
        return 'Mid'
    else:
        return 'Low'

# %%
rfm['Customer Value']=rfm.apply(func, axis=1)

# %%
rfm
# Out:
#               Recency  Frequency  Monetary  Clusters Customer Value
# Customer ID
# AA-10315     5.220356         11  8.623993         2           High
# AA-10375     2.995732         15  6.962613         3            Mid
# AA-10480     5.560682         12  7.490256         1            Low
# AA-10645     4.025352         18  8.534430         2           High
# AB-10015     6.030685          6  6.786886         1            Low
# ...               ...        ...       ...       ...            ...
# XP-21865     3.784190         28  7.772610         2           High
# YC-21895     1.609438          8  8.604169         3            Mid
# YS-21880     2.302585         12  8.812909         3            Mid
# ZC-21910     4.007333         31  8.990404         2           High
# ZD-21925     5.313206          9  7.309172         1            Low
#
# [793 rows x 5 columns]

# %%
# Present number of customers in each segment
rfm_values = rfm['Customer Value'].value_counts().sort_values(ascending=False)
rfm_values
# Out:
# Low     301
# High    273
# Mid     219
# Name: Customer Value, dtype: int64

# %%
# Create a scatter plot of the customer value clusters
plt.figure(figsize=(16, 8))
sns.scatterplot(x='Frequency', y='Recency', size='Monetary', hue='Customer Value', data=rfm, sizes=(5,200), palette='coolwarm')
# Out:
# <AxesSubplot: xlabel='Frequency', ylabel='Recency'>

# %% [markdown]
# The scatter plot above shows us that our high value customers are the ones who make the most frequent purchases. There is little relationship in the recency of our high value customers. Most purchases are around the same monetary value; and thus, did not have a huge affect on the clusters. Purchase frequency is the primary determinant between high value customers compared to low or mid value customers. Mid value customers have made less frequent purchases compared to high value customers, but have made purchases more recently than low value customers. Low value customers are the ones who have made few purchases and have not made a purchase recently.

# %%
# Add our customer segments to the main dataframe to develop insights regarding our customer segments.
df = pd.merge(df, rfm, on='Customer ID', how='left')
df['Year'] = df['Order Date'].dt.year
df.head(5)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City Postal Code  \
# 0      Claire Gute   Consumer  United States        Henderson       42420
# 1      Claire Gute   Consumer  United States        Henderson       42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles       90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale       33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale       33311
#
#    ...         Category Sub-Category  \
# 0  ...        Furniture    Bookcases
# 1  ...        Furniture       Chairs
# 2  ...  Office Supplies       Labels
# 3  ...        Furniture       Tables
# 4  ...  Office Supplies      Storage
#
#                                         Product Name   Sales   Recency  \
# 0                  Bush Somerset Collection Bookcase  261.96  5.826000
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94  5.826000
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62  2.995732
# 3      Bretford CR4500 Series Slim Rectangular Table  957.58  3.401197
# 4                     Eldon Fold 'N Roll Cart System   22.37  3.401197
#
#   Frequency  Monetary  Clusters  Customer Value  Year
# 0         5  7.046456         1             Low  2017
# 1         5  7.046456         1             Low  2017
# 2         9  7.020620         3             Mid  2017
# 3        15  7.864259         3             Mid  2016
# 4        15  7.864259         3             Mid  2016
#
# [5 rows x 23 columns]

# %%
# Calculate average customer lifespan (ACL) by customer value cohort
acl = df.groupby(['Customer ID']).agg({
                  'Order Date' : ['min', 'max']
                  })
acl.columns = ['Min', 'Max']
acl['Lifespan'] = acl['Max'] - acl['Min']
acl['Lifespan'] = acl['Lifespan'].dt.days
acl = pd.merge(acl, rfm, on='Customer ID', how='left')
acl[['Lifespan', 'Customer Value']]
# Out:
#              Lifespan Customer Value
# Customer ID
# AA-10315         1186           High
# AA-10375         1330            Mid
# AA-10480         1077            Low
# AA-10645         1232           High
# AB-10015          996            Low
# ...               ...            ...
# XP-21865         1397           High
# YC-21895         1135            Mid
# YS-21880         1074            Mid
# ZC-21910         1120           High
# ZD-21925         1019            Low
#
# [793 rows x 2 columns]

# %%
# Find mean customer lifespan for each customer value cohort. Convert lifespan from days to years
high_value_lifespan = (acl['Lifespan'].loc[acl['Customer Value'] == 'High'].mean()) / 365
mid_value_lifespan = (acl['Lifespan'].loc[acl['Customer Value'] == 'Mid'].mean()) / 365
low_value_lifespan = (acl['Lifespan'].loc[acl['Customer Value'] == 'Low'].mean()) / 365

# %%
# Create df of 2018 orders
df2018 = df.loc[df['Year'] == 2018]

# %%
# Create customer lifetime value (CLV) table
clv = df2018.groupby(['Customer Value']).agg({
    'Customer ID' : 'nunique',
    'Order ID' : 'nunique',
    'Sales' : 'sum'
})
clv.rename(columns={'Customer ID': 'Customer Count', 'Order ID': 'Order Count'}, inplace=True)

# %%
clv['Avg Sales Value'] = clv['Sales'] / clv['Order Count']
clv['Avg Purchase Frequency'] = clv['Order Count'] / clv['Customer Count']
clv['Avg Lifespan (Years)'] = [high_value_lifespan, low_value_lifespan, mid_value_lifespan]
clv['Customer Lifetime Value'] = clv['Avg Sales Value'] * clv['Avg Purchase Frequency'] * clv['Avg Lifespan (Years)']
clv
# Out:
#                 Customer Count  Order Count      Sales  Avg Sales Value  \
# Customer Value
# High                       259          735  395310.36       537.837224
# Low                        212          359   88071.77       245.325265
# Mid                        219          567  238669.69       420.934198
#
#                 Avg Purchase Frequency  Avg Lifespan (Years)  \
# Customer Value
# High                          2.837838              3.004084
# Low                           1.693396              2.288818
# Mid                           2.589041              2.962782
#
#                 Customer Lifetime Value
# Customer Value
# High                        4585.118630
# Low                          950.850287
# Mid                         3228.887323

# %%
high_clv = clv.loc['High', 'Customer Lifetime Value']
mid_clv = clv.loc['Mid', 'Customer Lifetime Value']
low_clv = clv.loc['Low', 'Customer Lifetime Value']
dif_mid_low = mid_clv - low_clv

print("Our high value customers have a customer lifetime value of ${:,.0f}, while mid value customers have a CLV of ${:,.0f} and low value have a CLV of ${:,.0f}. Converting low value customers to mid value customers will increase their CLV by ${:,.0f}. As we saw earlier, the primary difference between low value and mid value is that low value have not made a purchase recently. Let's see what products low value customers purchase.".format(high_clv, mid_clv, low_clv, dif_mid_low))
# Out:
# Our high value customers have a customer lifetime value of $4,585, while mid value customers have a CLV of $3,229 and low value have a CLV of $951. Converting low value customers to mid value customers will increase their CLV by $2,278. As we saw earlier, the primary difference between low value and mid value is that low value have not made a purchase recently. Let's see what products low value customers purchase.

# %%
df_low = df.copy()
df_low = df_low[df_low['Customer Value'] == 'Low']
df_low.head()
# Out:
#           Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1   CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 12  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 18  CA-2015-143336 2015-08-27 2015-09-01    Second Class    ZD-21925
# 19  CA-2015-143336 2015-08-27 2015-09-01    Second Class    ZD-21925
#
#          Customer Name   Segment        Country           City Postal Code  \
# 0          Claire Gute  Consumer  United States      Henderson       42420
# 1          Claire Gute  Consumer  United States      Henderson       42420
# 12        Andrew Allen  Consumer  United States        Concord       28027
# 18  Zuschuss Donatelli  Consumer  United States  San Francisco       94109
# 19  Zuschuss Donatelli  Consumer  United States  San Francisco       94109
#
#     ...         Category Sub-Category  \
# 0   ...        Furniture    Bookcases
# 1   ...        Furniture       Chairs
# 12  ...  Office Supplies        Paper
# 18  ...  Office Supplies          Art
# 19  ...       Technology       Phones
#
#                                          Product Name   Sales   Recency  \
# 0                   Bush Somerset Collection Bookcase  261.96  5.826000
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94  5.826000
# 12                                         Xerox 1967   15.55  5.560682
# 18                                         Newell 341    8.56  5.313206
# 19                            Cisco SPA 501G IP Phone  213.48  5.313206
#
#    Frequency  Monetary  Clusters  Customer Value  Year
# 0          5  7.046456         1             Low  2017
# 1          5  7.046456         1             Low  2017
# 12        12  7.490256         1             Low  2018
# 18         9  7.309172         1             Low  2015
# 19         9  7.309172         1             Low  2015
#
# [5 rows x 23 columns]

# %%
df_low['Sub-Category'].value_counts()
# Out:
# Binders        385
# Paper          325
# Furnishings    227
# Art            208
# Storage        194
# Phones         181
# Accessories    170
# Chairs         130
# Appliances     116
# Labels         100
# Tables          71
# Bookcases       66
# Envelopes       55
# Fasteners       50
# Supplies        44
# Machines        12
# Copiers          9
# Name: Sub-Category, dtype: int64

# %% [markdown]
# We can see the top 5 sub-category purchases of our low value customers were binders, paper, furnishings, art, and storage. These customers as whole have not made a recent purchase. Since several of these items wear down over time or get used, we should consider offering them one-time discounted pricing for these items to encourage purchasing our products again. We also may consider asking for customer feedback to better understand why they have not made a recent purchase.

# %%
# Let's see what products our high value customers purchase
df_high = df.copy()
df_high = df_high[df_high['Customer Value'] == 'High']
df_high['Sub-Category'].value_counts()
# Out:
# Binders        742
# Paper          671
# Furnishings    484
# Phones         462
# Storage        424
# Accessories    406
# Art            393
# Chairs         330
# Appliances     230
# Labels         173
# Tables         161
# Envelopes      138
# Fasteners      118
# Bookcases      105
# Supplies        96
# Machines        82
# Copiers         39
# Name: Sub-Category, dtype: int64

# %%
# Let's see what products our high value customers spend the most on
high_product_sales = df_high.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
high_product_sales
# Out:
# Sub-Category
# Chairs         193326.92
# Phones         177327.33
# Machines       150853.14
# Tables         121444.90
# Storage        121139.97
# Binders        113691.26
# Copiers        109258.84
# Accessories     85623.74
# Bookcases       60139.81
# Appliances      58496.32
# Furnishings     47081.24
# Paper           41078.25
# Supplies        37728.96
# Art             13252.14
# Envelopes        7615.09
# Labels           5655.59
# Fasteners        1642.70
# Name: Sales, dtype: float64

# %% [markdown]
# Our high value customers spend the most on chairs, phones, machines, tables, and storage. We can consider offering a loyalty program to these customers to encourage them to continue buying these products. We also may consider expanding our product offerings for these sub-categories as they generate the most sales amongst our best customers.
#
# Another option is again asking for customer feedback to understand the best aspects of these products so we can better market them to our low and mid tier customers.
